# %% [markdown]
# # Week 2 — The model is just a rule you can read
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/notebooks/02_your_first_readable_model.ipynb)
#
# You'll:
# 1. Write a **1-line hand rule** and rank pages with it.
# 2. Fit a **depth-2 decision tree** and `print` it — the model "learned" a readable if/else. Then compare — where does it beat your rule, and where doesn’t it?
# 3. See **why you never feed the outcome back in** — that's leakage.
#
# The payoff isn't a high score. It's: *my intuition was rough, the model found the real signal, and I can read exactly what it found.*

# %% [markdown]
# ## 0. Setup (Colab or local)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. A rule you write by hand: `stale x visible`
# Intuition: a page worth reviewing is one that is **stale** (not updated in a while) **and** still **visible** (getting impressions). Rank those by how much exposure they have.

# %%
stale   = (df["days_since_last_update"] >= 180).astype(int)
visible = (df["impressions_90d"] >= 500).astype(int)
df["hand_rule_score"] = stale * visible * df["impressions_90d"]

top10 = df.sort_values("hand_rule_score", ascending=False).head(10)
top10[["impressions_90d", "days_since_last_update", "avg_position", "ctr", "trend_direction"]]
# Out:
#        impressions_90d  days_since_last_update  avg_position   ctr  \
# 16751            61678                     194          19.7  0.15
# 16514            59472                     194          24.8  0.13
# 7021             25715                     194          22.2  0.23
# 21268            13299                     193          10.5  0.49
# 11489             7812                     194          39.0  0.01
# 12045             7558                     193          17.9  0.20
# 698               4590                     194          31.0  0.00
# 5327              4556                     194          16.4  0.33
# 26810             4429                     194          25.3  0.38
# 20837             1697                     193          15.8  0.12
#
#       trend_direction
# 16751            down
# 16514            down
# 7021             down
# 21268            down
# 11489            down
# 12045            down
# 698              down
# 5327             down
# 26810            down
# 20837            down

# %% [markdown]
# We need a way to score any ranking. **Precision@K** = of the top K pages a ranking flags, what fraction are actually declining.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

y = df["is_declining_label"].values
for k in (20, 50):
    print(f"Hand rule  Precision@{k}: {precision_at_k(df['hand_rule_score'], y, k):.3f}")
# Out:
# Hand rule  Precision@20: 0.900
# Hand rule  Precision@50: 0.680

# %% [markdown]
# ## 2. Let a model learn the rule — then read it
# A **depth-2 decision tree** can only ask 3 yes/no questions. That constraint is the point: whatever it learns, you can read.
#
# We give it a few **pre-decision** signals — never product flags.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0

# %% [markdown]
# That printout **is** the model — a human-readable if/else. Now rank pages by the tree's probability and score it the same way.

# %%
tree_score = tree.predict_proba(X)[:, 1]
for k in (20, 50):
    hr = precision_at_k(df["hand_rule_score"], y, k)
    tr = precision_at_k(tree_score, y, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")
# Out:
# Precision@20:  hand rule 0.900   vs   tree 0.550
# Precision@50:  hand rule 0.680   vs   tree 0.600

# %% [markdown]
# Look closely: the tree **wins at Precision@50** but your hand rule **wins at Precision@20**. Both results are real. A sharp human rule can be excellent at the very top of the list; the model's advantage shows up deeper, where simple rules run out of signal. Saying exactly that — instead of "the model is better" — is what honest evaluation sounds like.

# %% [markdown]
# ## 3. Why you can't feed the outcome back in
# Your label is `trend_direction == "down"`, and `trend_pct` is the exact percentage change that bucket is computed from — so it **is** the answer in disguise. Watch what happens if you feed it in as a feature:

# %%
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- word_count <= 212.00
# |   |   |--- class: 1
# |   |--- word_count >  212.00
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0

# %% [markdown]
# The tree just split on `trend_pct` and nailed the label — because the label is **derived from** `trend_pct`. That's **leakage**: the feature is the answer in disguise, and it teaches you nothing.
#
# That's also why the starter data ships **only observable signals** — the product's own decision flags (health scores, "needs CTR fix", and so on) aren't included, so you can't accidentally train on them. You build from what was knowable *before* the outcome.
#
# > Rule of thumb: if a feature would only be known *because someone already made the decision you're predicting*, it leaks. Leave it out.

# %% [markdown]
# ## 4. 🔧 Your turn
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.
#
# Write your experiment below.

# %%
# First thing, let's see what happens if the tree gets to ask more questions.
# going from depth 2 to depth 3 means one more split, so up to 7 questions instead of 3

from sklearn.tree import DecisionTreeClassifier, export_text

tree_d3 = DecisionTreeClassifier(max_depth=3, class_weight="balanced", random_state=42)
tree_d3.fit(X, y)
tree_d3_score = tree_d3.predict_proba(X)[:, 1]

print("Depth 3 tree, precision at 50:", round(precision_at_k(tree_d3_score, y, 50), 3))
print("Compare to depth 2 tree:", round(precision_at_k(tree_score, y, 50), 3))
print()
print(export_text(tree_d3, feature_names=features))

# worth checking honestly here, can you still read this tree in your head in a
# few seconds, or does it start feeling like a black box once you add more splits


# Second thing, dropping impressions_90d and adding engagement_rate in its place,
# then checking what the tree leans on first once that swap happens

features_swapped = ["content_age_days", "days_since_last_update","avg_position", "ctr", "word_count", "engagement_rate"]
X_swapped = df[features_swapped].replace([np.inf, -np.inf], np.nan).fillna(0)

tree_swapped = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree_swapped.fit(X_swapped, y)
swapped_score = tree_swapped.predict_proba(X_swapped)[:, 1]

print("Swapped features tree, precision at 50:", round(precision_at_k(swapped_score, y, 50), 3))
print()
print(export_text(tree_swapped, feature_names=features_swapped))

# whatever shows up at the very top of this printout is the first question the
# tree asks, that is the feature it found most useful once impressions_90d was
# taken off the table


# Third thing, the real check. everything above was scored in sample, meaning
# the tree got tested on the same rows it trained on, which is a bit like grading
# your own exam. splitting into train and test tells you if the tree actually
# generalizes or just memorized the data it saw

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

tree_holdout = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree_holdout.fit(X_train, y_train)
holdout_score = tree_holdout.predict_proba(X_test)[:, 1]

y_test_array = y_test.values if hasattr(y_test, "values") else y_test

# now the actual gap the notebook is asking about, hand rule vs tree, but this
# time on rows the tree has never seen, using X_test.index to pull the matching
# hand_rule_score values back out of df

test_hand_rule_score = df.loc[X_test.index, "hand_rule_score"].values

print("Comparing hand rule vs tree, on holdout data this time:")
for k in (20, 50):
    hr = precision_at_k(test_hand_rule_score, y_test_array, k)
    tr = precision_at_k(holdout_score, y_test_array, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")

print()
print("In sample tree precision at 50 for comparison:", round(precision_at_k(tree_score, y, 50), 3))
print("Holdout tree precision at 50:", round(precision_at_k(holdout_score, y_test_array, 50), 3))

# if the holdout tree number drops a fair amount compared to the in sample one,
# that gap is basically the tree looking better than it really is when it gets
# tested on data it already memorized. and if the hand rule still wins at
# precision at 20 even on unseen data, that tells you the earlier pattern from
# section 2 was not just a fluke of testing in sample
# Out:
# Depth 3 tree, precision at 50: 0.72
# Compare to depth 2 tree: 0.6
#
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- class: 0
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.33
# |   |   |   |--- class: 1
# |   |   |--- ctr >  0.33
# |   |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- avg_position <= 25.15
# |   |   |   |--- class: 0
# |   |   |--- avg_position >  25.15
# |   |   |   |--- class: 0
#
# Swapped features tree, precision at 50: 0.7
#
# |--- avg_position <= 0.55
# |   |--- avg_position <= 0.15
# |   |   |--- class: 0
# |   |--- avg_position >  0.15
# |   |   |--- class: 0
# |--- avg_position >  0.55
# |   |--- content_age_days <= 287.50
# |   |   |--- class: 1
# |   |--- content_age_days >  287.50
# |   |   |--- class: 0
#
# Comparing hand rule vs tree, on holdout data this time:
# Precision@20:  hand rule 0.700   vs   tree 0.650
# Precision@50:  hand rule 0.580   vs   tree 0.680
#
# In sample tree precision at 50 for comparison: 0.6
# Holdout tree precision at 50: 0.68

# %% [markdown]
# ### Save your work
# **Colab:** *File → Save a copy in GitHub* (your submission) and *File → Save a copy in Drive*.
#
# You now have the two core reflexes of applied ML: **discover before you model**, and **prefer a model you can read and can't fool**. That's the whole foundation the capstone builds on.

# %% [markdown]
# ### My experiment results
#
# Going from depth 2 to depth 3, precision at 50 went from 0.60 to 0.72, so a real
# improvement. The depth 3 tree is still short enough to read in a few seconds, though
# a few branches end up predicting the same class on both sides of a split, meaning
# those extra questions weren't actually adding useful signal, just extra depth for
# its own sake.
#
# Dropping impressions_90d and adding engagement_rate, the tree's first split changed
# from impressions_90d to avg_position, so once impressions was off the table,
# avg_position became the strongest signal instead. Precision at 50 with the swapped
# features came out at 0.70, close to the depth 3 result and better than the original
# depth 2 tree at 0.60.
#
# On holdout data, the hand rule beat the tree at precision at 20 (0.700 vs 0.650),
# but the tree beat the hand rule at precision at 50 (0.680 vs 0.580). This matches
# the same pattern the notebook showed in section 2, the hand rule is sharper right
# at the very top of the list, while the tree's advantage shows up once you look
# deeper. So the gap from section 2 held up even on data the tree had never seen,
# this isn't just an in sample fluke.
#
# One odd thing worth noting honestly: the holdout tree's precision at 50 (0.68) came
# out slightly higher than the in sample tree's (0.60). Normally holdout performance
# should be equal to or worse than in sample, since the model trained on the in sample
# data. This is most likely just noise from this particular train test split rather
# than a real effect, observed only.
